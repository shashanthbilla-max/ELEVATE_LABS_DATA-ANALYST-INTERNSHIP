# %% [markdown]
# # Titanic Dataset - Exploratory Data Analysis (EDA)
#
# Objective: Extract insights using visual and statistical exploration using Pandas, Matplotlib, and Seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize']=(8,5)

df = pd.read_csv('train.csv')
df.head()

# %% [markdown]
# ## Dataset Information

# %%
df.info()
df.describe(include='all')

# %%
df.isnull().sum()

# %%
df['Survived'].value_counts()

# %% [markdown]
# ## Data Cleaning

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df.drop('Cabin', axis=1, inplace=True)

df.isnull().sum()

# %% [markdown]
# ## Histogram - Age Distribution

# %%
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# Observation: Most passengers were between 20 and 40 years old.

# %% [markdown]
# ## Boxplot - Fare

# %%
sns.boxplot(y=df['Fare'])
plt.title('Fare Outliers')
plt.show()

# %% [markdown]
# Observation: Fare contains several extreme outliers.

# %% [markdown]
# ## Survival by Gender

# %%
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title('Survival by Gender')
plt.show()

# %% [markdown]
# Observation: Female passengers had a higher survival rate.

# %% [markdown]
# ## Survival by Passenger Class

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title('Survival by Passenger Class')
plt.show()

# %% [markdown]
# Observation: First-class passengers survived more often.

# %% [markdown]
# ## Scatter Plot - Age vs Fare

# %%
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived')
plt.title('Age vs Fare')
plt.show()

# %% [markdown]
# Observation: Higher fare passengers generally had better survival outcomes.

# %% [markdown]
# ## Correlation Heatmap

# %%
temp = df.copy()
temp['Sex'] = temp['Sex'].map({'male':0,'female':1})
temp['Embarked'] = temp['Embarked'].astype('category').cat.codes

plt.figure(figsize=(10,6))
sns.heatmap(temp.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Observation: Sex and Passenger Class show strong relationships with survival.

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(temp[['Survived','Pclass','Age','Fare']])
plt.show()

# %% [markdown]
# ## Summary Findings
#
# 1. Females had a much higher survival rate than males.
# 2. First-class passengers were more likely to survive.
# 3. Higher fare passengers had better survival chances.
# 4. Most passengers were aged between 20 and 40.
# 5. Fare contains several outliers.
# 6. Passenger class and gender are important predictors of survival.
