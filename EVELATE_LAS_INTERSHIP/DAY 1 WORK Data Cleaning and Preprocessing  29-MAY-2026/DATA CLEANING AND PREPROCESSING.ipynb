# %%
import numpy as numpy
import pandas as pd

# %%
df=pd.read_csv("D:/EVELATE_LAS_INTERSHIP/DAY 1 WORK Data Cleaning and Preprocessing  29-MAY-2026/customer_churn_with_dates.csv")

# %%
df
# Out:
#       customerID        Date  gender  SeniorCitizen Partner Dependents  \
# 0     7590-VHVEG  26-12-2024  Female              0     Yes         No
# 1     5575-GNVDE  24-11-2024    Male              0      No         No
# 2     3668-QPYBK  23-06-2024    Male              0      No         No
# 3     7795-CFOCW  28-04-2025    Male              0      No         No
# 4     9237-HQITU  17-09-2025  Female              0      No         No
# ...          ...         ...     ...            ...     ...        ...
# 7038  6840-RESVB  17-06-2025    Male              0     Yes        Yes
# 7039  2234-XADUH  08-01-2024  Female              0     Yes        Yes
# 7040  4801-JZAZL  03-05-2025  Female              0     Yes        Yes
# 7041  8361-LTMKD  10-08-2024    Male              1     Yes         No
# 7042  3186-AJIEK  20-07-2025    Male              0      No         No
#
#       tenure PhoneService     MultipleLines InternetService  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Date              7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %% [markdown]
# Null values are missing data in a dataset.
#
# That means some information is absent, empty, or unknown.

# %%
df.isnull().sum()
# Out:
# customerID          0
# Date                0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# duplicates:Duplicate data means the same information appears more than once in a dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['gender'] = df['gender'].str.lower()

# %%
df.columns
# Out:
# Index(['customerID', 'Date', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip().str.lower()

# %%
df.columns
# Out:
# Index(['customerID', 'Date', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
df
# Out:
#       customerID        Date  gender  SeniorCitizen Partner Dependents  \
# 0     7590-vhveg  26-12-2024  female              0     yes         no
# 1     5575-gnvde  24-11-2024    male              0      no         no
# 2     3668-qpybk  23-06-2024    male              0      no         no
# 3     7795-cfocw  28-04-2025    male              0      no         no
# 4     9237-hqitu  17-09-2025  female              0      no         no
# ...          ...         ...     ...            ...     ...        ...
# 7038  6840-resvb  17-06-2025    male              0     yes        yes
# 7039  2234-xaduh  08-01-2024  female              0     yes        yes
# 7040  4801-jzazl  03-05-2025  female              0     yes        yes
# 7041  8361-ltmkd  10-08-2024    male              1     yes         no
# 7042  3186-ajiek  20-07-2025    male              0      no         no
#
#       tenure PhoneService     MultipleLines InternetService  ...  \
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15076\2394721818.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df.sort_values('Date')
# Out:
#       customerID       Date  gender  SeniorCitizen Partner Dependents  tenure  \
# 3337  0840-dfezh 2024-01-01  female              0      no         no       7
# 3276  4210-qfjmf 2024-01-01  female              0      no         no       4
# 231   3316-uwxuy 2024-01-01    male              0      no         no      50
# 2854  4644-pizrt 2024-01-01    male              0     yes        yes      17
# 885   4661-njeux 2024-01-01    male              0      no         no       1
# ...          ...        ...     ...            ...     ...        ...     ...
# 5058  1376-hhbdv 2025-12-31  female              0      no         no      30
# 2484  6476-epyzr 2025-12-31    male              0     yes        yes      12
# 322   8705-wzcyl 2025-12-31    male              0      no         no       1
# 6598  6169-pgncd 2025-12-31  female              0      no         no      57
# 176   2656-fmokz 2025-12-31  female              1      no         no      15
#
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#       customerid       date  gender  seniorcitizen partner dependents  tenure  \
# 0     7590-vhveg 2024-12-26  female              0     yes         no       1
# 1     5575-gnvde 2024-11-24    male              0      no         no      34
# 2     3668-qpybk 2024-06-23    male              0      no         no       2
# 3     7795-cfocw 2025-04-28    male              0      no         no      45
# 4     9237-hqitu 2025-09-17  female              0      no         no       2
# ...          ...        ...     ...            ...     ...        ...     ...
# 7038  6840-resvb 2025-06-17    male              0     yes        yes      24
# 7039  2234-xaduh 2024-01-08  female              0     yes        yes      72
# 7040  4801-jzazl 2025-05-03  female              0     yes        yes      11
# 7041  8361-ltmkd 2024-08-10    male              1     yes         no       4
# 7042  3186-ajiek 2025-07-20    male              0      no         no      66
#
# ...

# %%
df.dtypes
# Out:
# customerid                  object
# date                datetime64[ns]
# gender                      object
# seniorcitizen                int64
# partner                     object
# dependents                  object
# tenure                       int64
# phoneservice                object
# multiplelines               object
# internetservice             object
# onlinesecurity              object
# onlinebackup                object
# deviceprotection            object
# techsupport                 object
# streamingtv                 object
# streamingmovies             object
# contract                    object
# paperlessbilling            object
# paymentmethod               object
# monthlycharges             float64
# totalcharges                object
# churn                       object
# dtype: object
